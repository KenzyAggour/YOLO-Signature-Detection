# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.4/40.4 kB 1.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 749.6/749.6 kB 18.2 MB/s eta 0:00:0000:01
# ...

# %%
from ultralytics import YOLO
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
model = YOLO('yolov8m.yaml')

# %%
model.train(data = '/kaggle/input/yaml-formated-file/config.yaml' , 
            epochs = 20 , seed = 3 , batch = 5)
# Out:
# Ultralytics YOLOv8.1.45 🚀 Python-3.10.13 torch-2.1.2 CUDA:0 (Tesla P100-PCIE-16GB, 16276MiB)
# ...

# %%
def detect(img_path):
    img = cv2.imread(img_path)
    det = model(img)
    det = det[0].plot()
    return det

res = detect('/kaggle/input/signatures/SignatureObjectDetection/Train/images/10.tif')
plt.imshow(res)
# Out:
# 0: 640x640 1 signature, 15.2ms
# Speed: 4.4ms preprocess, 15.2ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)

# %%
res = detect('/kaggle/input/signatures/SignatureObjectDetection/Test/images/682.tif')
plt.imshow(res)
# Out:
# 0: 640x640 2 signatures, 15.3ms
# Speed: 3.7ms preprocess, 15.3ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
